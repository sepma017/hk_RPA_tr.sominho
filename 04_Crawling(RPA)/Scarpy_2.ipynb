# %% [markdown]
# # Scrapy
# `pip install scrapy`

# %% [markdown]
# ## xpath
# * css-selector 역할 해주는 문법

# %%
import scrapy
import requests
from scrapy.http import TextResponse # xpath 연습

# %% [markdown]
# ### xpath 사용 방법
# * 다음 추천검색어 첫 번째 xpath
# ```
# //*[@id="wrapSearch"]/div[3]/ul[3]/li[1]/a
# ```
# ```
# body #wrapSearch > div:nth-child(3) > ul:nth-child(3) > li:nth-child(1) > a
# ```
#
# **xpath 구성 요소**
# * `//` : 가장 상위 엘리먼트
# * `*` : 조건에 맞는 하위 엘리먼트를 모두 살펴봄
#     * `div .txt`
#     * 후손 선택자의 역할
# * `[@id="wrapSearch"]` : 조건 : `id`가 `wrapSearch`인 엘리먼트
# * `/` : 바로 아래 엘리먼트를 살펴봄.
#     * `div > .txt`
#     * 자식 선택자의 역할
# * `div[3]` : div 태그에서 3 번째 엘리먼트를 선택
#     * 1부터 시작

# %%
from fake_useragent import UserAgent
# 웹 페이지 연결
headers = {"User-Agent" : UserAgent().chrome}
response = requests.get("http://corners.gmarket.co.kr/Bestsellers", headers=headers)

# TextResponse 객체 생성
text_response = TextResponse(response.url, body=response.text, encoding='utf-8')

# %%
text_response.xpath('//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li[1]/a')
# Out:
# [<Selector xpath='//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li[1]/a' data='<a class="itemname" href="http://item...'>]

# %% [markdown]
# `data` : xpath selector로 선택된 엘리먼트

# %%
# 텍스트만 선택하기 - data를 text로 지정
text_response.xpath('//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li[1]/a/text()')
# Out:
# [<Selector xpath='//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li[1]/a/text()' data='자녀교육서 골라담기'>]

# %%
# TextResponse 객체에서 data만 가져오기
text_response.xpath('//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li[1]/a/text()').extract()
# Out:
# ['자녀교육서 골라담기']

# %%
# attribute만 가져오고 싶으면 @attribute이름
text_response.xpath('//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li[1]/a/@href').extract()
# Out:
# ['http://item.gmarket.co.kr/Item?goodscode=2300760539&ver=637745798447313511']

# %%
text_response.xpath('//*[@id="gBestWrap"]/div/div[3]/div[2]/ul/li/a/text()').extract()
# Out:
# ['자녀교육서 골라담기',
#  '서귀포인정 고당도 타이벡 감귤12brix 5kg 로얄(2S-M)',
#  '[파격조건]고메 함박스테이크 152gX10개',
#  '아보카도  중과 11과(2세트 구매시 4개증정)',
#  '[쟈뎅]아워티 오렌지 자몽 블랙티 10P+10P/차',
#  '수퍼맘스토리카페/2022년 다이어리/쎈다/2권 1세트',
#  '[광천김]광천김 파래 도시락김5g X 32봉 + 리빙박스 쿠폰8630원',
#  '[유한킴벌리]크리넥스3겹 데코소프트33MX24롤X2팩',
#  '[온더바디]발을씻자 코튼 풋 샴푸 385ml 레몬+자몽+쿨링',
#  '[아카페라]빙그레 아카페라 바닐라라떼 240mlx20펫 /커피음료',
#  '[스파클]스파클 생수 500ml 20병 5팩 (총100병)',
#  '[드릴펑]배수구 세정제 드릴펑 1L 3+2개(총5개)/쿠폰가8100원',
#  '순수본가 소갈비살 200g X 4개+생와사비/ 미국 EXCEL',
#  '[영실업] [공식] 시크릿쥬쥬 나만의 매직캐리어',
#  '31건어물 참쥐포 (대) 10장 + 10장(쿠폰가 7425원)',
#  '[분홍코끼리](대전신세계)[분홍코끼리](쫀득몰드창) 가벼워 털 메리제인슈즈(1cm)',
#  '[메디플라워]에트투스 트리트먼트 헤어팩 /헤어케어 아르간 1000ml',
#  '[비비고]비비고 사골곰탕 500g 18봉',
#  '홈쇼핑 FW 기모 이너웨어/니트/팬츠/원피스 外',
#  '초등 국어 일등급 독해력 + 일등급 어휘력 전2권 1~6 단계별 선택구매',
#  '청정우 차돌박이 (3초구이 샤브용) 250gX3팩',
#  '[플레이맥스][플레이맥스] [베스트 특가찬스 무료배송]엄마 까투리 말하는 병원놀이 18pcs /말하는 ',
#  '참닭 춘천 닭갈비 700g+700g/찜닭/갈비/양념육',
#  '[니](무료반품)NII 기모슬랙스/데님팬츠류+쿠폰혜택',
#  '[블랙야크키즈](대전신세계)블랙야크키즈 21F/W 신상 구스롱다운자켓 2종 택 1 ( BKS베이직L다운자켓   BKO루즈핏L다운...',
#  '실속포장 햇 반건시 곶감 10입+10입/40g내외 쿠폰11930',
#  '[진라면]진라면 매운맛 40봉',
#  '[풀무원]풀무원 얇은피만두 9종 10봉세트 모음',
#  'AdBlue 요소수 10리터 VDA 국내 당일발송 ISO 22241',
#  '[화이트샌즈][최초판매가 43 000원] 공용 후리스 이어머프 버킷햇 (6 colors)',
#  '(놀이대전)(공식판매처) 에버랜드 종일이용권(~12/31)',
#  '[이사도라]신상 입고완료 퍼부츠/털단화/롱부츠외 BEST 36종',
#  '재미마주 나의 학급문고 시리즈 (전12권)_12월20일 순차발송',
#  '[락토핏]15+15% 종근당건강 락토핏 5X 생유산균 골드 3통 +증정',
#  '국산 3중 비말차단 마스크 200매 KF-AD MB필터 마스크',
#  '팔주머니 플리츠 기모 웜웨어 세트',
#  '특가) 삼성출판사 명작동화 스티커북 10+1 전11종 세트',
#  '[비비고]셰프의 노하우  CJ 비비고 잔칫집 모듬잡채 644g 3봉',
#  '[구글플레이](카드가능) 기프트코드 10만원 / 구글 기프트카드',
#  '조선호텔 포기김치 8kg 100년 전통의 프리미엄 김치',
#  '달콤한 부사 햇 사과 4.5KG (26-30과)/13brix 이상',
#  '기모 맨투맨 티셔츠 오버핏 남성 남자 후드티 후리스',
#  '[중모토이] 플러스 2021형 베스파 미니 전동 스쿠터',
#  '문학수첩 해리포터 전 23권 세트',
#  '[광동]위생천 75ml x 30병',
#  '[다샵]KF94 국산 컬러 마스크 새부리형 식약처인증 개별포장',
#  '[릴리유][하기스] 릴리유 퓨어골드 물티슈 72캡X20팩',
#  '[리복](신세계강남점)리복 운동화 런닝화 2종 메모리 퓨어폼 발편한 쿠션화 RUNNER 5.0  H00909 H00916',
#  '[풀무원]풀무원  얇은피만두 12봉 노엣지 피자 7판 골라담기',
#  '[스파클](쿠폰적용가 11180원) 스파클생수 2L 30병',
#  'GSfresh 밥값하는쌀20kg(21년산)',
#  '[시매쓰]생각하는 유아수학 유아 (전6종)',
#  '출근길 너무 추워요/지마켓/세빈/패딩/카고/조거팬츠',
#  '[비비고]비비고 사골곰탕 500g 18개',
#  '[햇반]CJ 햇반 210g 36개 1박스',
#  '[하우쎈스]크리스마스트리 풀세트 1.0M-1.6M 사이즈선택',
#  '[오뚜기]육개장 컵라면 104Gx24개',
#  '[미스타셰프]미스타셰프 버섯뚝배기불고기 400g 4팩/반찬/증정',
#  '[브라운물티슈]브라운 아기물티슈 네이처 마일드 70매 캡형 10+10팩',
#  '[양반]동원 양반 밤단팥죽 285g x 10개',
#  '[맥심]모카골드 커피믹스 180Tx2개+벤티텀블러: 36500원 쿠폰',
#  '[포레스트스토리]B7 약산성 탈모 샴푸 1000ml+1000ml+250ml+헤어에센스',
#  '모노시크/기모티셔츠/맨투맨/니트/상하세트/트레이닝',
#  '[가나양말]남녀 학생 발목 중목 스포츠 양말 2세트+1켤레사은품',
#  '[카누]카누 미니 마일드 120Tx2개 총240T : 공유의 커피 ~',
#  '[삼성전자](JU) SL-T1670W 정품무한 잉크젯 삼성복합기 프린터',
#  '[베베앙]베베앙 아기물티슈  시그니처 대용량 100매 캡형 10팩',
#  '[글라스락]글라스락 렌지쿡 계란찜용 705ml_2조 /간편요리 라면기',
#  '[CJ고메]고메 통등심돈카츠 3팩 + 돈카츠소스1개',
#  '무료반품 메이시스 겨울신상 뽀글이 니트 기모티',
#  '[밀크마일]밀크 귀욤 겨울신상 깜짝할인 상하복/티셔츠/레깅스외',
#  '[팬콧키즈]캐릭터 아동 방한 실내화 샌들 초등 유아 키즈',
#  '[모나리자]보타닉 블라썸 (27m30롤)X3개 화장지 휴지',
#  '100%강원도 통더덕 무침_13팩(21.10월햇더덕사용)',
#  '연모 세트 : 한희정 대본집  한희정',
#  '[의성마늘햄]의성마늘 프랑크 70gx30개',
#  '[순수식품]rTG 알티지 오메가3 비타민D 6개월분(180캡슐)',
#  '[Gfresh]나래 굴림 고기만두 168g10봉/전자렌지(쿠폰가14900원)',
#  '[코카콜라]코크제로355ml캔 24입',
#  '[맥심]모카골드 커피믹스 180T+180T +벤티텀블러/쿠폰가36500',
#  '[헤드앤숄더]헤드앤숄더 기프트팩 샴푸1900ml구성+컨디셔너1개',
#  '무형광 미쁘 핸드타올  2겹5000매 페이퍼타올 핸드타월',
#  '[에바스]로에랑스 퍼퓸 바디미스트/샤워코롱 250ml(+행사중)',
#  '[닥터그루트]닥터그루트 스마일패키지 +앰플증정',
#  '(아웃백/이디야) 페이즈기프트 Foodcafe 5만원권',
#  '프리랑 1+1 겨울신상 맨투맨/니트/블라우스/원피스',
#  '[Gfresh]바다내음 통통생굴 2Kg /횟감용 15%+10%쿠폰가 26900원',
#  '[연세우유][연세우유] 멸균 흰우유 48팩',
#  '[유니픽쳐]타투 아이브로우 1+1+눈썹가이드3종 증정 최대7일지속',
#  '[구글플레이](카드가능) 기프트코드 5만원 / 구글 기프트카드',
#  '밥상마루 전통 떡국 8개 / 간편식',
#  '[미샤]12월 미샤 연말 선물세트 특가전 UP TO 50% Off',
#  '[샘표]양조간장 701 1.7L+501 500ml 특별기획',
#  '(놀이공원할인대전) 롯데월드 어드벤처 종합이용권',
#  '[다산]후 한국사 선택구매(전40종)',
#  '[Gfresh]반야월할매 당면만두 3kg/쿠폰가 16800원',
#  '[무슈제이]클래식 아쿠아 에센스 올인원 155ml 1+1',
#  '시크폭스 겨울신상/티셔츠/팬츠/니트/기모아이템',
#  '(명품향수)아덴外 버버리/불가리/페라가모/향수특가',
#  '비비고 왕교자1.05kg 3개',
#  '[리큐]액체세탁세제 리큐 일반 2.1Lx6개+증정3종/16430원',
#  '[동원참치]고추참치 100g 15캔',
#  '[베이비베이비]베이비베이비 아기물티슈 트윙클120매 20팩 캡형',
#  '[유한킴벌리]크리넥스 비말차단 에어마스크 화이트대형50매(1BOX)',
#  '[네파][네파] 공용 듀오리버시블 후디 구스다운 7G72027',
#  '[헬로]헬로 순수 3겹 천연펄프 화장지 30m 30롤 3팩 특가행사',
#  '[박스포유]100%직접생산/ 박스포유 택배박스',
#  '[비비고][시중동일상품]비비고 사골곰탕500g 18봉',
#  '[고기천국](고기천국) 미국오리지널 왕목살(구이용) 400g+400g',
#  '[유한킴벌리]크리넥스3겹 울트라클린27MX30롤X2팩',
#  '[맥심]맥심 모카골드 커피믹스 400T : 커피는 맥심~',
#  '수피랑 천연펄프 화장지 휴지 순수 3겹 30롤 3팩 +P',
#  '농협 우리쌀 20KG(21년산)',
#  '맥심 모카골드 커피믹스 180T+180T 총360T',
#  '[클라이드앤][클라이드앤] 남성용아웃포켓 후드 푸퍼_CKDDU413M',
#  '[뮬라웨어]22%+10% 뮬라웨어 윈터페스타 레깅스/자켓 추천 Vol.1',
#  '제이와이북스 에반무어 세트 선택 구매',
#  '[쟈뎅]아워티 베리썸 히비스커스 티 10P+10P/차',
#  '더미누 해피 미리크리스마스 할인펑펑 초특가',
#  '수맘 따뜻한 수면 잠옷 원피스 홈웨어 세트',
#  '[에어데이즈]에어데이즈 KF94 새부리형 국산 마스크 대형 50매',
#  '사과즙 애플순 110ml x 80포 / 쿠폰 15%',
#  '[아이프리]세탁소용 보풀제거기 FX-814 / 전기식+충전식 겸용',
#  '[알새우칩]알새우칩68g 20개입 박스',
#  '[Gfresh]버팔로치킨윙봉 1kg+1kg',
#  '(책읽는곰) 그림책이 참 좋아 세트별 선택구매 / 신간구성 세트 오픈',
#  '데이뮤즈 양털/원피스/패딩/니트/후드집업/맨투맨/롱',
#  '[오리온]간식이필요해 크리스마스파티 팩',
#  '양파 국내산 무안 양파 5kg(소)',
#  '[맥심]화이트골드 커피믹스  180Tx2개 총360T: 연아의커피~',
#  '영의정 호두왕찹쌀떡 (80gX20개)',
#  '[에어데이즈]에어데이즈 마스크 KF94 국산 새부리형 대형 50매',
#  '[LG전자]LG 프라이빗 스마트 스크린 27ART10AKPL 스탠바이미TV',
#  '[썬몬드]베지밀 야채가득v19 145ml x 72팩',
#  '[에디션앤드지]김선호 데일리 블렌드 라운드 니트 9종 NEB4ER1901',
#  '[비룡소]비룡소 주나이다 그림책 시리즈 (전3권)_의+괴물원+길',
#  '[별똥별]뛰뛰빵빵핸드북/부릉부릉씽씽 선택구매(세이펜 미포함)',
#  '[아워홈]지리산수 블루 2L 24병 /생수전문배송',
#  '[할리스]할리스 바닐라 딜라이트 10T x3박스',
#  '[파스퇴르]파스퇴르 전용목장190mL 저지방 멸균우유18입',
#  '[아침농산](21년산/혼합/보통) 농부의아침 쌀10kg 쿠폰가 23180원',
#  '[스파오]스파오 도톰 기모 맨투맨/팬츠/패딩',
#  '[농심]안성탕면 125g 5개입 멀티팩 X 8개 BOX',
#  '[HP]250 G8-4F2T1PA 정품Win10탑재 인강용 사무용 재택근무',
#  '(사회평론) 용선생의 시끌벅적 과학교실 26-27 전2권',
#  '[서울우유]멸균우유 1000ml x 10입 (1박스)',
#  '쉬블림로브 9900균일 신상뽀글이 맨투맨 니트 롱 후드',
#  '[바나나맛우유]바나나키즈 우유 120mlx24팩 +판박이스티커',
#  '[풀무원]풀무원  토이쿠키 만들기 2종 혼합 골라담기 (3박스구성)',
#  '[애경]순샘 주방세제 베리 3LX2개',
#  '[시크릿데이]런칭 10810원 시크릿데이 유기농 미피 한정판 생리대',
#  '[홈스타]홈스타 락스와세제 후로랄파인 750MLx4',
#  '[맥콜]맥콜 160ml 30캔x2 (총60캔) / 탄산음료',
#  '태안 자연산 통통 활 갑오징어 1kg4-8미/25%할인9680원',
#  '[크리오]덴티메이트시즌2 초극세모 총30개',
#  '[뉴케어]뉴케어 구수한맛 200ml x 30팩 /완전 균형영양식 식사',
#  '엑소(EXXO) A4 복사용지(A4용지) 75g 2BOX(5000매)',
#  '[종근당건강]15%+15% 아이클리어 루테인 지아잔틴 3박스',
#  '[더블에이]더블에이 A4 복사용지  80g 4000매 2BOX/A4용지',
#  '[삼성물산]삼성 레드 A4용지 복사용지 80g 2500매 2박스(5000매)',
#  '한라산농장 황금향 10KG 랜덤1택(소/중/대) 쿠폰할인중',
#  '[마즈]베스트 3종 100gX18개 (1BOX)',
#  '[Gfresh]가시제거 노르웨이고등어 대 900g (쿠폰가 14180원)',
#  '[동원에프앤비]동원 라이트 스탠다드 참치 150g 원터치 10개',
#  '글램공감/브라1+팬티2/속옷세트/A~D컵/빅사이즈',
#  'F1 Adblue 차량용 요소수 10L / 국내배송 / 당일발송',
#  '고시히카리초밥세트 30입 ',
#  '블프 남녀공용 오리털 파카 덕다운 후드 겨울패딩',
#  '[제주삼다수]제주삼다수 2L 12병 /생수전문배송',
#  '[아이러브베베]피치 엠보 100매X캡형 8팩 아기물티슈 스마일배송',
#  '[밀카]스트로베리바 37g 12개+ 오레오바 37g 12개 총24개',
#  '[메가박스](메가박스) 2D 일반관 예매권',
#  '무료배송 페이퍼맥스 고양이 종이컵 2000개/1박스',
#  '[농협](전단상품)믿고먹는안심농협쌀20KG 포 ',
#  '{애플특전} 옹성우 (ONG SEONG WU) - 2022 SEASON’S GREETINGS (2022 시즌그리팅)',
#  '[구글플레이](카드가능) 기프트코드 20만원 / 구글 기프트카드',
#  '[릴리유]릴리유 퓨어퍼플 물티슈 캡72매X10팩(1BOX)',
#  '[아이러브베베]아이러브베베물티슈핑크100매캡형X20팩',
#  '[CJ제일제당]CJ제일제당 T 햇반 흑미밥 작은공기 130g 36개',
#  '클랩 추천 크리스마스 시리즈 + 마들린느 그림책 세트(14종) 크리스마스 선물',
#  '겨울/혹한기/균일가/플리스/라이닝/트레이닝복',
#  '한라산농장 황금향 5KG 랜덤1택(소/중/대) 고당도 특가',
#  '해남 꿀 고구마 3kg+3kg',
#  '[구글플레이](카드가능) 기프트코드 1만원 / 구글 기프트카드',
#  '[오뚜기밥]맛있는 오뚜기밥 210g x 24개입(1박스)',
#  '[듀라셀]듀라셀 알카라인 건전지 AA 20개입 x 2개 + 사은품',
#  '(행사상품)N 동서식품맥심모카골드믹스230T 2760G ',
#  '[이니스프리]UP TO 50% 2021 마지막 빅세일',
#  '[아르떼(Arte)]아르떼 새부리형 마스크 KF94 100매 화이트 개별포장',
#  '쇼인더룸 특가 기모맨투맨/티셔츠/빅사이즈/세트',
#  '로드블링 겨울특가 기모 세트/맨투맨/기모/니트/바지',
#  '[매일유업]매일두유 99.9 190ml 48팩',
#  '[신라면]농심 신라면컵 30개',
#  '(다산) 흔한남매 불꽃 튀는 우리말 1-4 전4권',
#  '[리스테린]리스테린 쿨민트750ml4 + 검케어100ml + 펌프',
#  '[GNM자연의품격]루테인지아잔틴 오메가3 루테인 3박스(총 3개월분)',
#  '[커피빈](커피빈) 모바일교환권 3만원권',
#  '[파스퇴르]파스퇴르 무항생제 바른목장우유 195mL 36입',
#  '[나무야나무야]나무야 도톰한 3겹데코 30m 30롤 3팩/화장지/휴지',
#  '[쉬크]쉬크 하이드로5 커스텀 하이드레이트 싱글팩(면도기1+날15+폼1+케이스1).']
