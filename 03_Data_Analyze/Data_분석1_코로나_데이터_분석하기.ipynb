# %% [markdown]
# # 라이브러리 import

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 데이터 불러오기

# %%
corona = pd.read_csv("./data/covid_19_clean_complete.csv")
corona.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %% [markdown]
# # 데이터 프레임 정보 확인

# %%
corona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  object
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 3.7+ MB

# %% [markdown]
# ## 결측값(NaN) 확인하는 팁

# %%
corona.isnull().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %% [markdown]
# # 데이터 타입 수정하기
# * `Date` 컬럼이 날짜 타입(`datetime`) 형식으로 안되어 있으니까 바꿔주자

# %%
corona['Date'] = pd.to_datetime(corona['Date'])
corona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  datetime64[ns]
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(3)
# memory usage: 3.7+ MB

# %% [markdown]
# # 코로나 국가별 최근 확진자, 사망자, 회복자 데이터 분석

# %% [markdown]
# ## 최근 데이터 추출

# %%
# 최근 날짜 마스크 만들기
recent_mask = corona['Date'] == max(corona['Date'])

# 최근 데이터만 추출
corona_recent = corona[recent_mask]
corona_recent.head()
# Out:
#       Province/State Country/Region       Lat       Long       Date  \
# 48807            NaN    Afghanistan  33.93911  67.709953 2020-07-27
# 48808            NaN        Albania  41.15330  20.168300 2020-07-27
# 48809            NaN        Algeria  28.03390   1.659600 2020-07-27
# 48810            NaN        Andorra  42.50630   1.521800 2020-07-27
# 48811            NaN         Angola -11.20270  17.873900 2020-07-27
#
#        Confirmed  Deaths  Recovered  Active             WHO Region
# 48807      36263    1269      25198    9796  Eastern Mediterranean
# 48808       4880     144       2745    1991                 Europe
# 48809      27973    1163      18837    7973                 Africa
# 48810        907      52        803      52                 Europe
# 48811        950      41        242     667                 Africa

# %% [markdown]
# # 국가별 합계 구하기

# %%
column_names = ["Confirmed", "Deaths", "Recovered"]
corona_recent_sum_by_country = corona_recent.groupby("Country/Region")[column_names].sum()
corona_recent_sum_by_country.head()
# Out:
#                 Confirmed  Deaths  Recovered
# Country/Region
# Afghanistan         36263    1269      25198
# Albania              4880     144       2745
# Algeria             27973    1163      18837
# Andorra               907      52        803
# Angola                950      41        242

# %%
corona_recent_sum_by_country = corona_recent_sum_by_country.reset_index()
corona_recent_sum_by_country.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered
# 0    Afghanistan      36263    1269      25198
# 1        Albania       4880     144       2745
# 2        Algeria      27973    1163      18837
# 3        Andorra        907      52        803
# 4         Angola        950      41        242

# %% [markdown]
# # 사망자가 많은 순으로 정렬

# %%
corona_death_sort = corona_recent_sum_by_country.sort_values(by="Deaths", ascending=False)
corona_death_sort
# Out:
#      Country/Region  Confirmed  Deaths  Recovered
# 173              US    4290259  148011    1325804
# 23           Brazil    2442375   87618    1846641
# 177  United Kingdom     301708   45844       1437
# 111          Mexico     395489   44022     303810
# 85            Italy     246286   35112     198593
# ..              ...        ...     ...        ...
# 94             Laos         20       0         19
# 68        Greenland         14       0         13
# 30         Cambodia        226       0        147
# 69          Grenada         23       0         23
# 114        Mongolia        289       0        222
#
# [187 rows x 4 columns]

# %%
corona_death_sort.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
# #T_2b767_row0_col1,#T_2b767_row0_col2,#T_2b767_row1_col3{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_2b767_row0_col3{
#             background-color:  #d42121;
#             color:  #f1f1f1;
#         }#T_2b767_row1_col1{
#             background-color:  #f4503a;
#             color:  #000000;
#         }#T_2b767_row1_col2{
#             background-color:  #f24734;
#             color:  #000000;
#         }#T_2b767_row2_col1,#T_2b767_row15_col3{
#             background-color:  #fee9df;
#             color:  #000000;
#         }#T_2b767_row2_col2{
#             background-color:  #fca78b;
#             color:  #000000;
#         }#T_2b767_row2_col3,#T_2b767_row14_col3,#T_2b767_row17_col3,#T_2b767_row19_col3,#T_2b767_row41_col3,#T_2b767_row47_col1,#T_2b767_row47_col3,#T_2b767_row50_col1,#T_2b767_row51_col1,#T_2b767_row51_col3,#T_2b767_row53_col2,#T_2b767_row53_col3,#T_2b767_row54_col2,#T_2b767_row55_col1,#T_2b767_row55_col2,#T_2b767_row55_col3,#T_2b767_row56_col2,#T_2b767_row57_col1,#T_2b767_row57_col2,#T_2b767_row57_col3,#T_2b767_row58_col2,#T_2b767_row59_col2,#T_2b767_row60_col1,#T_2b767_row60_col2,#T_2b767_row61_col2,#T_2b767_row62_col2,#T_2b767_row63_col1,#T_2b767_row63_col2,#T_2b767_row64_col1,#T_2b767_row64_col2,#T_2b767_row64_col3,#T_2b767_row65_col2,#T_2b767_row66_col1,#T_2b767_row66_col2,#T_2b767_row66_col3,#T_2b767_row67_col2,#T_2b767_row68_col1,#T_2b767_row68_col2,#T_2b767_row69_col1,#T_2b767_row69_col2,#T_2b767_row69_col3,#T_2b767_row70_col2,#T_2b767_row71_col1,#T_2b767_row71_col2,#T_2b767_row72_col1,#T_2b767_row72_col2,#T_2b767_row72_col3,#T_2b767_row73_col1,#T_2b767_row73_col2,#T_2b767_row73_col3,#T_2b767_row74_col1,#T_2b767_row74_col2,#T_2b767_row74_col3,#T_2b767_row75_col1,#T_2b767_row75_col2,#T_2b767_row75_col3,#T_2b767_row76_col1,#T_2b767_row76_col2,#T_2b767_row76_col3,#T_2b767_row77_col2,#T_2b767_row78_col1,#T_2b767_row78_col2,#T_2b767_row79_col2,#T_2b767_row80_col1,#T_2b767_row80_col2,#T_2b767_row80_col3,#T_2b767_row81_col1,#T_2b767_row81_col2,#T_2b767_row81_col3,#T_2b767_row82_col1,#T_2b767_row82_col2,#T_2b767_row83_col1,#T_2b767_row83_col2,#T_2b767_row83_col3,#T_2b767_row84_col2,#T_2b767_row85_col1,#T_2b767_row85_col2,#T_2b767_row85_col3,#T_2b767_row86_col1,#T_2b767_row86_col2,#T_2b767_row86_col3,#T_2b767_row87_col1,#T_2b767_row87_col2,#T_2b767_row87_col3,#T_2b767_row88_col1,#T_2b767_row88_col2,#T_2b767_row89_col2,#T_2b767_row90_col1,#T_2b767_row90_col2,#T_2b767_row90_col3,#T_2b767_row91_col1,#T_2b767_row91_col2,#T_2b767_row91_col3,#T_2b767_row92_col1,#T_2b767_row92_col2,#T_2b767_row92_col3,#T_2b767_row93_col1,#T_2b767_row93_col2,#T_2b767_row93_col3,#T_2b767_row94_col1,#T_2b767_row94_col2,#T_2b767_row94_col3,#T_2b767_row95_col1,#T_2b767_row95_col2,#T_2b767_row96_col1,#T_2b767_row96_col2,#T_2b767_row96_col3,#T_2b767_row97_col1,#T_2b767_row97_col2,#T_2b767_row97_col3,#T_2b767_row98_col1,#T_2b767_row98_col2,#T_2b767_row98_col3,#T_2b767_row99_col1,#T_2b767_row99_col2,#T_2b767_row99_col3,#T_2b767_row100_col1,#T_2b767_row100_col2,#T_2b767_row100_col3,#T_2b767_row101_col1,#T_2b767_row101_col2,#T_2b767_row101_col3,#T_2b767_row102_col1,#T_2b767_row102_col2,#T_2b767_row102_col3,#T_2b767_row103_col1,#T_2b767_row103_col2,#T_2b767_row103_col3,#T_2b767_row104_col1,#T_2b767_row104_col2,#T_2b767_row104_col3,#T_2b767_row105_col1,#T_2b767_row105_col2,#T_2b767_row105_col3,#T_2b767_row106_col1,#T_2b767_row106_col2,#T_2b767_row106_col3,#T_2b767_row107_col1,#T_2b767_row107_col2,#T_2b767_row107_col3,#T_2b767_row108_col1,#T_2b767_row108_col2,#T_2b767_row108_col3,#T_2b767_row109_col1,#T_2b767_row109_col2,#T_2b767_row109_col3,#T_2b767_row110_col1,#T_2b767_row110_col2,#T_2b767_row110_col3,#T_2b767_row111_col1,#T_2b767_row111_col2,#T_2b767_row111_col3,#T_2b767_row112_col1,#T_2b767_row112_col2,#T_2b767_row112_col3,#T_2b767_row113_col1,#T_2b767_row113_col2,#T_2b767_row113_col3,#T_2b767_row114_col1,#T_2b767_row114_col2,#T_2b767_row114_col3,#T_2b767_row115_col1,#T_2b767_row115_col2,#T_2b767_row115_col3,#T_2b767_row116_col1,#T_2b767_row116_col2,#T_2b767_row116_col3,#T_2b767_row117_col1,#T_2b767_row117_col2,#T_2b767_row117_col3,#T_2b767_row118_col2,#T_2b767_row119_col1,#T_2b767_row119_col2,#T_2b767_row119_col3,#T_2b767_row120_col1,#T_2b767_row120_col2,#T_2b767_row120_col3,#T_2b767_row121_col1,#T_2b767_row121_col2,#T_2b767_row121_col3,#T_2b767_row122_col1,#T_2b767_row122_col2,#T_2b767_row122_col3,#T_2b767_row123_col1,#T_2b767_row123_col2,#T_2b767_row123_col3,#T_2b767_row124_col1,#T_2b767_row124_col2,#T_2b767_row124_col3,#T_2b767_row125_col1,#T_2b767_row125_col2,#T_2b767_row125_col3,#T_2b767_row126_col1,#T_2b767_row126_col2,#T_2b767_row126_col3,#T_2b767_row1 ...

# %% [markdown]
# # 시간에 따른 확진자, 사망자, 회복자

# %% [markdown]
# ## 날짜별 확진자, 사망자, 회복자 합계 구하기

# %%
column_names = ["Confirmed", "Deaths", "Recovered"]

corona_date = corona.groupby("Date")[column_names].sum()
corona_date.head()
# Out:
#             Confirmed  Deaths  Recovered
# Date
# 2020-01-22        555      17         28
# 2020-01-23        654      18         30
# 2020-01-24        941      26         36
# 2020-01-25       1434      42         39
# 2020-01-26       2118      56         52

# %% [markdown]
# ## 시간에 따른 누적 확진자, 사망자, 회복자 시각화

# %%
plt.figure(figsize=(22, 10))
plt.xticks(rotation=45)
sns.lineplot(data=corona_date)
plt.show()

# %% [markdown]
# # folium을 이용한 지도 시각화

# %% [markdown]
# ## folium 사용 방법

# %%
import folium

f_map = folium.Map()
f_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_49bcfa9639cc4ed3a93624df14cca95b%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_49bcfa9639cc4ed3a93624df14cca95b%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_49bcfa9639cc4ed3a93624df14cca95b%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_49bcfa9639cc4ed3a93624df14cca95b%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0%2C%200%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs%3A%2 ...

# %% [markdown]
# ## folium으로 월드메르디앙 빌딩 찍어보기

# %%
location = [37.5256967,126.888587]

f_map = folium.Map(location=location)
f_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f51a985a641d44a39d73c7680c49d936%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f51a985a641d44a39d73c7680c49d936%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f51a985a641d44a39d73c7680c49d936%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f51a985a641d44a39d73c7680c49d936%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5256967%2C%20126.888587%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# #### 확대

# %%
f_map = folium.Map(location=location, zoom_start=17)
f_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_a735a7f3d142408f9ccdf66835872182%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_a735a7f3d142408f9ccdf66835872182%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_a735a7f3d142408f9ccdf66835872182%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_a735a7f3d142408f9ccdf66835872182%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5256967%2C%20126.888587%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ### 마커 활용하기 - 기본 마커

# %%
f_map = folium.Map(location=location, zoom_start=17)

folium.Marker(
    location=location, # 마커의 좌표
    popup="코딩지옥", # 마커 클릭하면 나오는 팝업 메세지
    icon=folium.Icon(color="red", icon="star") # 아이콘 모양
).add_to(f_map)

f_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_2bc7f9214cf644ca9aba081ee3903edc%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_2bc7f9214cf644ca9aba081ee3903edc%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_2bc7f9214cf644ca9aba081ee3903edc%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_2bc7f9214cf644ca9aba081ee3903edc%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5256967%2C%20126.888587%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# ### 원형 마커

# %%
f_map = folium.Map(location=location, zoom_start=17)

folium.CircleMarker(
    location,
    radius = 100,    # 반지름
    color="#F7D358", # 테두리 색상
    fill=True,       # 원 안쪽 채우기
    fill_color="#08088A", # 원 안쪽 채울 색상
    popup="점심밥 먹는 곳"
).add_to(f_map)

f_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_4b9ae7945cad4282b57394990058254e%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_4b9ae7945cad4282b57394990058254e%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_4b9ae7945cad4282b57394990058254e%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_4b9ae7945cad4282b57394990058254e%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B37.5256967%2C%20126.888587%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %% [markdown]
# # 전 세계 코로나 바이러스 감염 지도 표시

# %%
corona_recent.head()
# Out:
#       Province/State Country/Region       Lat       Long       Date  \
# 48807            NaN    Afghanistan  33.93911  67.709953 2020-07-27
# 48808            NaN        Albania  41.15330  20.168300 2020-07-27
# 48809            NaN        Algeria  28.03390   1.659600 2020-07-27
# 48810            NaN        Andorra  42.50630   1.521800 2020-07-27
# 48811            NaN         Angola -11.20270  17.873900 2020-07-27
#
#        Confirmed  Deaths  Recovered  Active             WHO Region
# 48807      36263    1269      25198    9796  Eastern Mediterranean
# 48808       4880     144       2745    1991                 Europe
# 48809      27973    1163      18837    7973                 Africa
# 48810        907      52        803      52                 Europe
# 48811        950      41        242     667                 Africa

# %%
column_names = ["Country/Region", "Lat", "Long", "Confirmed"]
corona_recent_data = corona_recent.loc[:, column_names]
corona_recent_data
# Out:
#               Country/Region        Lat       Long  Confirmed
# 48807            Afghanistan  33.939110  67.709953      36263
# 48808                Albania  41.153300  20.168300       4880
# 48809                Algeria  28.033900   1.659600      27973
# 48810                Andorra  42.506300   1.521800        907
# 48811                 Angola -11.202700  17.873900        950
# ...                      ...        ...        ...        ...
# 49063  Sao Tome and Principe   0.186400   6.613100        865
# 49064                  Yemen  15.552727  48.516388       1691
# 49065                Comoros -11.645500  43.333300        354
# 49066             Tajikistan  38.861000  71.276100       7235
# 49067                Lesotho -29.610000  28.233600        505
#
# [261 rows x 4 columns]

# %% [markdown]
# ### 인덱스 재구성 - `reset_index`

# %%
corona_recent_data.reset_index() # 원본 인덱스를 컬럼으로 따로 빼준다.
# Out:
#      index         Country/Region        Lat       Long  Confirmed
# 0    48807            Afghanistan  33.939110  67.709953      36263
# 1    48808                Albania  41.153300  20.168300       4880
# 2    48809                Algeria  28.033900   1.659600      27973
# 3    48810                Andorra  42.506300   1.521800        907
# 4    48811                 Angola -11.202700  17.873900        950
# ..     ...                    ...        ...        ...        ...
# 256  49063  Sao Tome and Principe   0.186400   6.613100        865
# 257  49064                  Yemen  15.552727  48.516388       1691
# 258  49065                Comoros -11.645500  43.333300        354
# 259  49066             Tajikistan  38.861000  71.276100       7235
# 260  49067                Lesotho -29.610000  28.233600        505
#
# [261 rows x 5 columns]

# %%
corona_recent_data = corona_recent_data.reset_index(drop=True) # 원본 인덱스는 삭제하고 재구성
corona_recent_data.head()
# Out:
#   Country/Region       Lat       Long  Confirmed
# 0    Afghanistan  33.93911  67.709953      36263
# 1        Albania  41.15330  20.168300       4880
# 2        Algeria  28.03390   1.659600      27973
# 3        Andorra  42.50630   1.521800        907
# 4         Angola -11.20270  17.873900        950

# %%
import numpy as np
f_map = folium.Map(location=[0, 0], zoom_start=3)

for idx in corona_recent_data.index:
    # 위경도
    lat = corona_recent_data["Lat"][idx]
    lng = corona_recent_data["Long"][idx]
    # 나라 이름
    c_name = corona_recent_data["Country/Region"][idx]
    # 누적 확진자
    confirmed = corona_recent_data["Confirmed"][idx]
    
    folium.CircleMarker(
        location=[lat, lng],
        radius=np.log(confirmed) * 2,
        popup=f"{c_name} / {confirmed}☣",
        color='red',
        fill=True,
        fill_color='red'
    ).add_to(f_map)

f_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f8ea5ac4c24e4db781e92f88e2e8ad06%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f8ea5ac4c24e4db781e92f88e2e8ad06%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_f8ea5ac4c24e4db781e92f88e2e8ad06%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_f8ea5ac4c24e4db781e92f88e2e8ad06%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B0.0%2C%200.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20crs% ...
